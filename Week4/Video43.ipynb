# %% [markdown]
# <a href="https://colab.research.google.com/github/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week4/Video43.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video 4.3: Solving differential equations

# %% [markdown]
# ## Video

# %%
# @markdown 
from IPython.display import YouTubeVideo
video = YouTubeVideo(id="rSMn_aU_XgA", width=730, height=410, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video
# Out:
# Video available at https://youtube.com/watch?v=rSMn_aU_XgA

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/4twh6/download">
#     Click here to download notes
# </a>

# %%
# @markdown
from IPython.display import IFrame
IFrame(src="https://mfr.osf.io/render?url=https://osf.io/4twh6/?direct%26mode=render%26action=download%26mode=render", width=730, height=1000)
# Out:
#         <iframe
#             width="730"
#             height="1000"
#             src="https://mfr.osf.io/render?url=https://osf.io/4twh6/?direct%26mode=render%26action=download%26mode=render"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
