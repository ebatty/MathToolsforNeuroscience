# %% [markdown]
# # Video 1.2: Vector properties & operations

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(YouTubeVideo(id=f"7AXpa4U4j-M", width=730, height=410, fs=1))
display(out)
# Out:
# Video available at https://youtube.com/watch?v=7AXpa4U4j-M

# %% [markdown]
# 0:06 Introduction
# 0:31 Vector length
# 1:47 Unit vectors
# 2:50 Zero vectors
# 3:24 Scalar multiple
# 4:52 Vector addition
# 7:48 Dot product
# 10:22 Neuroscience example
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=06s" target="_blank" > 00:06</a> Introduction
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=31s" target="_blank" > 0:31</a> Vector length
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=107s" target="_blank" > 01:47</a>  Unit vectors
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=170s" target="_blank" > 01:50</a>  Zero vectors
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=204s" target="_blank" > 03:24</a> Scalar multiplication
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=252s" target="_blank" > 04:52</a> Vector addition
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=468s" target="_blank" > 07:48</a>  Dot product
#
# <a href="https://www.youtube.com/watch?v=7AXpa4U4j-M&t=622s" target="_blank" > 10:22</a>  Neuroscience example

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/4t5j3/download">
#     Click here to download notes
# </a>

# %% [markdown]
# <img src="https://github.com/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week1/video1_2_notes.png?raw=True" alt="notes for the video" class="bg-primary" width="100%">
