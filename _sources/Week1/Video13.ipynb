# %% [markdown]
# # Video 1.3: Vector spaces

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(YouTubeVideo(id=f"kqaRSwyL050", width=730, height=410, fs=1))
display(out)
# Out:
# Video available at https://youtube.com/watch?v=kqaRSwyL050

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/wyck6/download">
#     Click here to download notes
# </a>

# %% [markdown]
# <img src="https://github.com/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week1/video1_3_notes.png?raw=True" alt="notes for the video" class="bg-primary" width="100%">
