# %% [markdown]
# <a href="https://colab.research.google.com/github/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week2/Video25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video 2.5: Nonsquare matrices as transformations between dimensions (3Blue1Brown)

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(YouTubeVideo(id=f"v8VSDg_WQlA", width=730, height=410, fs=1))
display(out)
# Out:
# Video available at https://youtube.com/watch?v=v8VSDg_WQlA
