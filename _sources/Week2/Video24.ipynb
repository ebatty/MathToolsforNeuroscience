# %% [markdown]
# <a href="https://colab.research.google.com/github/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week2/Video24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video 2.4: Inverse matrices, column space, and null space (3Blue1Brown)

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(YouTubeVideo(id=f"uQhTuRlWMxw", width=730, height=410, fs=1))
display(out)
# Out:
# Video available at https://youtube.com/watch?v=uQhTuRlWMxw
