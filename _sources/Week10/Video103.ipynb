# %% [markdown]
# <a href="https://colab.research.google.com/github/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week10/Video103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video 10.3: Model selection

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(YouTubeVideo(id=f"_gDs-8acgdE", width=730, height=410, fs=1))
display(out)
# Out:
# Video available at https://youtube.com/watch?v=_gDs-8acgdE

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/mhcpx/download">
#     Click here to download notes
# </a>

# %% [markdown]
# <img src="https://github.com/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week10/video10_3_notes.png?raw=True" alt="notes for the video" class="bg-primary" width="100%">
