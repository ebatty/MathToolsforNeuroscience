# %% [markdown]
# <a href="https://colab.research.google.com/github/ebatty/MathToolsforNeuroscience/blob/jupyterbook/Week3/Video32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video 3.2: Discrete Dynamical Neural Circuit

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(YouTubeVideo(id=f"vN05gWmdAt8", width=730, height=410, fs=1))
display(out)
# Out:
# Video available at https://youtube.com/watch?v=vN05gWmdAt8

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/rv247/download">
#     Click here to download notes
# </a>

# %%
# @markdown
from IPython.display import IFrame
from ipywidgets import widgets
out = widgets.Output()
with out:
    display(IFrame(src=f"https://mfr.osf.io/render?url=https://osf.io/rv247/?direct%26mode=render%26action=download%26mode=rende", width=730, height=410))
display(out)
# Out:
#         <iframe
#             width="730"
#             height="1000"
#             src="https://mfr.osf.io/render?url=https://osf.io/rv247/?direct%26mode=render%26action=download%26mode=render"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
